# %% [markdown]
# # Trilateration Method for Talocrural and Subtalar Ankle Joint Characterization

# %% [markdown]
# In the following cell, the initial base and platform definitions and dimensions are declared, and the rest position extracted by using the measuring tool from the SolidWorks CAD model.

# %%
#Trilateration method for ankle localization

from sage.plot.plot3d.shapes2 import *

# Rotation axis in a unitary vector and angle in degrees
def rot_ax_ang(u,a):
    #degrees to radians
    alpha=a*pi/180
    na=(1-cos(alpha))
    ca=cos(alpha)
    sa=sin(alpha)
    #rotation matrix
    R=matrix([[u[0]^2*na+ca, u[0]*u[1]*na-u[2]*sa, u[0]*u[2]*na+u[1]*sa],
            [u[0]*u[1]*na+u[2]*sa, u[1]^2*na+ca, u[1]*u[2]*na-u[0]*sa],
            [u[2]*u[0]*na-u[1]*sa, u[2]*u[1]*na+u[0]*sa, u[2]^2*na+ca]])
    return R

pvar=1 #variation factor
#Talocrural direction
TCa1=-6*pvar
TCa2=80*pvar
vTC=rot_ax_ang([0,0,1], TCa1)*rot_ax_ang([1,0,0], TCa2)*vector([0,0,1])
#Subtalar direction
STa1=23*pvar
STa2=41*pvar
vST=rot_ax_ang([0,0,1], STa1)*rot_ax_ang([0,1,0], STa2)*vector([1,0,0])

#Anthropometric values
#vK=12;vL=11;vO=16;vP=1;vQ=5;vR=0.54 #anthropometric measurements
vK=12*pvar;vL=11*pvar;vO=16*pvar;vP=1*pvar;vQ=5*pvar;vR=0.54*pvar #anthropometric measurements
#H=1750 #heigth in mm
H=1750*pvar #heigth in mm
d_m=(0.285-0.039)*H/2 #knee-ankle half distance
d_p=0.039*H #ankle-foot
z_p=-(d_m+d_p) # z initial position 
ae=2*pi/3 #auxiliar angle
PO=vector([0,0,0]) #Origin at middle shank

#real data from the Turmellmeter 
from sage.plot.plot3d.transform import rotate_arbitrary
z0=100
# base centroid
cb=vector([116.666,97.905,0])
angrot =(79.91/2)*(pi/180)
mrotz = rotate_arbitrary((0.0,0.0,1.0),angrot)

#base Draw-wire sensor module A centerpoint
A= vector([0,0,0])  - cb
A= mrotz*A

#text keywords
kwds = {'color':'black','fontsize':24,'fontweight':'bold','rotation':30}

#Ap plataform vertice initial position
Ap0= vector([30,-0.67,-z0]) + A 
lbl = text3d('A',A+vector([10,10,10]),**kwds)

#base Draw-wire sensor module B centerpoint
B= vector([297.73,0,0]) - cb
B= mrotz*B
#Ap plataform vertice initial position
Bp0 = vector([-25.67,90.99, -z0]) + B
lbl += text3d('B',B+vector([10,10,10]),**kwds)

#Cp initial position
C=vector([52.268,293.716,0]) - cb
C= mrotz*C
Cp0 = vector([-26.4,-92.6,-z0]) + C
lbl += text3d('C',C+vector([10,10,10]),**kwds)

#base points
#radius of the tethraedron base
rtb=32.76
#tetrahedron A base points 
bt1A=vector([31.9,-7.44,0])
bt2A=vector([-9.51,31.5,0])
bt3A=vector([-22.39,-23.91,0])
A1=bt1A+A
lbl += text3d('A1',A1+vector([10,10,10]),**kwds)
A2=bt2A+A
lbl += text3d('A2',A2+vector([10,10,10]),**kwds)
A3=bt3A+A
lbl += text3d('A3',A3+vector([10,10,10]),**kwds)
#tetrahedron B base points 
bt1B=vector([27.44,-17.9,0])
bt2B=vector([1.79,32.71,0])
bt3B=vector([-29.42,-14.81,0])
B1=bt1B+B
lbl += text3d('B1',B1+vector([10,10,10]),**kwds)
B2=bt2B+B
lbl += text3d('B2',B2+vector([10,10,10]),**kwds)
B3=bt3B+B
lbl += text3d('B3',B3+vector([10,10,10]),**kwds)
#tetrahedron C base points 
bt1C=vector([32.52,3.92,0])
bt2C=vector([-19.66,26.21,0])
bt3C=vector([-12.87,-30.13,0])
C1=bt1C+C
lbl += text3d('C1',C1+vector([10,10,10]),**kwds)
C2=bt2C+C
lbl += text3d('C2',C2+vector([10,10,10]),**kwds)
C3=bt3C+C
lbl += text3d('C3',C3+vector([10,10,10]),**kwds)
#tetrahedron triangles base
t1=polygon([A1,A2,A3,A1],color='green')
t2=polygon([B1,B2,B3,B1],color='green')
t3=polygon([C1,C2,C3,C1],color='green')


#platform
tp=polygon([Ap0,Bp0,Cp0,Ap0])
lA1=line3d([Ap0,A1],color='black')
lA2=line3d([Ap0,A2],color='black')
lA3=line3d([Ap0,A3],color='black')
lB1=line3d([Bp0,B1],color='black')
lB2=line3d([Bp0,B2],color='black')
lC1=line3d([Cp0,C1],color='black')
lC3=line3d([Cp0,C3],color='black')
linesp=lA1+lA2+lA3+lB1+lB2+lC1+lC3

#initial platform position
A0=Ap0
B0=Bp0
C0=Cp0
PM0=(A0+B0+C0)/3 #center of the platform

#dots representation
dot=point3d((0,0,0),size=3,color='red',opacity=1)
dPO=dot.translate(PO)
dA0=dot.translate(A0)
dB0=dot.translate(B0)
dC0=dot.translate(C0)
dPM0=dot.translate(PM0)
dA1=dot.translate(A1)
dA2=dot.translate(A2)
dA3=dot.translate(A3)
dB1=dot.translate(B1)
dB2=dot.translate(B2)
dC1=dot.translate(C1)
dC3=dot.translate(C3)
dotsp=dA0+dB0+dC0+dPM0
dotsb=dA1+dA2+dA3+dB1+dB2+dC1+dC3

tb = lbl+t1+t2+t3+tp+linesp+dotsp+dotsb

tb.show(viewer='tachyon', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=4.8, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 2), # the camera is slightly tilted
    viewdir=(-2.0,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1)
tb.save('realdim.png', viewer='tachyon', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=4.8, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 2), # the camera is slightly tilted
    viewdir=(-2.0,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1
    )
# Out:
# Graphics3d Object

# %% [markdown]
# In the following cell, the foot position is symbolically represented by using the Product of Exponentials Formula. Simulating the foot at initial position.

# %%
#ankle model
r_1=vector([0,0,Ap0[2]]).n()/2 #intersection point between the talocrural axis and the sagittal plane
ap=0.039*H 
lp=0.152*H

#points on the malleolar medial and lateral
M_1=r_1-ap*vR*vTC
M_2=r_1+ap*(1-vR)*vTC
tht=(STa2*pi/180)

#subtalar axis and the sagittal plane intersection 
r_2=(vQ*vector([-cos(tht),0,-sin(tht)])+r_1).n()

#points from the hindfoot to the midfoot
N_1=r_2+0.6*lp*vR*vST
N_2=r_2-0.3*lp*vR*vST

#representation of the kinematic chain
lrt=line([PO,r_1])
lm12=line([M_1,M_2])
ln12=line([N_1,N_2])
lrA=line([r_2,A0])
lrB=line([r_2,B0])
lrC=line([r_2,C0])

#markers representation
dr1=dot.translate(r_1)
dr2=dot.translate(r_2)
dM1=dot.translate(M_1)
dM2=dot.translate(M_2)
dN1=dot.translate(N_1)
dN2=dot.translate(N_2)

#reference labels
plbl=vector([0,0,8])
lbp = text3d('PO',PO+plbl)
lbp += Text('A0',color='black').translate(A0++plbl)
lbp += text3d('B0',B0++plbl)
lbp += text3d('C0',C0++plbl)
lbp += text3d('PM0',PM0++plbl)
#axes labels
lbf = text3d('M1',M_1++plbl)
lbf += text3d('M2',M_2++plbl)
lbf += text3d('N1',N_1++plbl)
lbf += text3d('N2',N_2++plbl)
lbf += text3d('r1',r_1++plbl)
lbf += text3d('r2',r_2++plbl)


#finding the twist unitary vectors 
w1=n((M_1-M_2)/abs(M_1-M_2))
w2=n((N_1-N_2)/abs(N_1-N_2))

#the perpendicular component
v1=n(-w1.cross_product(r_1))
v2=n(-w2.cross_product(r_2))

#angles for the talocrural and subtalar rotations
theta1=var('theta_1')
theta2=var('theta_2')

#six dimensional vector xi mapping 
xi1=matrix([v1[0],v1[1],v1[2],w1[0],w1[1],w1[2]]).transpose()
xi2=matrix([v2[0],v2[1],v2[2],w2[0],w2[1],w2[2]]).transpose()

#transformation of exponential matrix of rotation
Rexp1=rot_ax_ang(w1,theta1)

#rotation matrix component of the homogeneous transformation
vexp1=(matrix.identity(3)-Rexp1)*(w1.cross_product(v1))

#conformation of the homogeneous transformation matrix
MTH1=(Rexp1.augment(vexp1)).stack(vector([0,0,0,1]))

#components for the subtalar axis
Rexp2=rot_ax_ang(w2,theta2)
vexp2=(matrix.identity(3)-Rexp2)*(w2.cross_product(v2))
MTH2=(Rexp2.augment(vexp2)).stack(vector([0,0,0,1]))

#transformation matrix representing the initial position
gst0A=matrix([[1,0,0,A0[0]],[0,1,0,A0[1]],[0,0,1,A0[2]],[0,0,0,1]])
gst0B=matrix([[1,0,0,B0[0]],[0,1,0,B0[1]],[0,0,1,B0[2]],[0,0,0,1]])
gst0C=matrix([[1,0,0,C0[0]],[0,1,0,C0[1]],[0,0,1,C0[2]],[0,0,0,1]])
gst0PM=matrix([[1,0,0,PM0[0]],[0,1,0,PM0[1]],[0,0,1,PM0[2]],[0,0,0,1]])

#product of exponential matrices for all the points
MTHA=MTH1*MTH2*gst0A
MTHB=MTH1*MTH2*gst0B
MTHC=MTH1*MTH2*gst0C
MTHPM=MTH1*MTH2*gst0PM

#components of the group of rigid movements for the central point
f_xpm=MTHPM[0][3]
f_ypm=MTHPM[1][3]
f_zpm=MTHPM[2][3]
#orthogonal direction vectors
f_spm=vector([MTHPM[0][0],MTHPM[1][0],MTHPM[2][0]])
f_npm=vector([MTHPM[0][1],MTHPM[1][1],MTHPM[2][1]])
f_apm=vector([MTHPM[0][2],MTHPM[1][2],MTHPM[2][2]])

#components of the three vertices of the plattform
f_xA=MTHA[0][3]
f_yA=MTHA[1][3]
f_zA=MTHA[2][3]
f_xB=MTHB[0][3]
f_yB=MTHB[1][3]
f_zB=MTHB[2][3]
f_xC=MTHC[0][3]
f_yC=MTHC[1][3]
f_zC=MTHC[2][3]

Fpm3=vector([f_xpm,f_ypm,f_zpm])
Fa3=vector([f_xA,f_yA,f_zA])
Fb3=vector([f_xB,f_yB,f_zB])
Fc3=vector([f_xC,f_yC,f_zC])

# %% [markdown]
# In the following cell, specific angles are applied to the symbolic formula. Representing a new foot position regarding the shank.

# %%
#change rotation angles, theta_1=[-30,30], theta_2=[-30,30], A and B apexes workspace must never cut the base plane.
th1=0
th2=0
Api=Fa3.subs(theta_1=th1,theta_2=th2).n()
Bpi=Fb3.subs(theta_1=th1,theta_2=th2).n()
Cpi=Fc3.subs(theta_1=th1,theta_2=th2).n()

#platform simulated
tps=polygon([Api,Bpi,Cpi,Api])
#lenghts simulated
lA1s=line3d([Api,A1], radius =2)
lA2s=line3d([Api,A2], radius =2)
lA3s=line3d([Api,A3], radius =2)
lB1s=line3d([Bpi,B1], radius =2)
lB2s=line3d([Bpi,B2], radius =2)
lC1s=line3d([Cpi,C1], radius =2)
lC3s=line3d([Cpi,C3], radius =2)
sb=t1+t2+t3+tps+lA1s+lA2s+lA3s+lB1s+lB2s+lC1s+lC3s


sb.show(aspect_ratio=1, viewer= 'threejs',frame=false,
        projection='orthographic', axes = false)
sb.save('simdim.png', viewer='tachyon', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[4, 4, 2], # a distant camera position combined with 
    zoom=4.8, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 2), # the camera is slightly tilted
    viewdir=(-2.8,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1
    )
# Out:
# Graphics3d Object

# %% [markdown]
# In the following cell, the sensor measurements simulated and from the CAD model in SolidWorks

# %%
# Sensor measurements
#s1=norm(Api-A1)
s1=110
#s1=102
#s1=94
#s1=85.6

#s2=norm(Api-A2)
s2=126
#s2=117
#s2=108
#s2=98.9

#s3=norm(Api-A3)
s3=125
#s3=116
#s3=108
#s3=99.5

#s4=norm(Bpi-B1)
s4=148
#s4=152
#s4=156
#s4=160

#s5=norm(Bpi-B2)
s5=108
#s5=113
#s5=117
#s5=122

#s6=norm(Cpi-C1)
s6=152
#s6=155
#s6=158
#s6=160

#s7=norm(Cpi-C3)
s7=119
#s7=122
#s7=125
#s7=127
print(s1,s2,s3,s4,s5,s6,s7)
# Out:
# 110 126 125 148 108 152 119

# %% [markdown]
# In the following cell, the trilateration method is applied for the firs point estimation. First three circles are drawed.

# %%
la1m=s1
la2m=s2
la3m=s3
s1c=circle(A1,s1,thickness=2, color='magenta')
s2c=circle(A2,s2,thickness=2, color='magenta')
s3c=circle(A3,s3,thickness=2, color='magenta')
baseA=polygon([A1, A2, A3], color='orange')
tetra=s1c+s2c+s3c+baseA
tetra.show(camera_position=[30,25,295], viewpoint= [[-0.3,-0.3,-1],100])
# Out:
# Graphics3d Object

# %% [markdown]
# Three circle definitions, solving for two circles in the plane solving for the first two to found the perpendicular line.

# %%
x,y = var(['x','y'])
As1=(x-A1[0])^2+(y-A1[1])^2==la1m^2
As2=(x-A2[0])^2+(y-A2[1])^2==la2m^2
As3=(x-A3[0])^2+(y-A3[1])^2==la3m^2
sln1=solve([As1,As2],[x,y])
ps1x1=sln1[0][0].right()
ps1y1=sln1[0][1].right()
ps1x2=sln1[1][0].right()
ps1y2=sln1[1][1].right()
ls1=line3d([[ps1x1, ps1y1, 0],[ps1x2,ps1y2,0]],thickness=2,radius =2)
tetra+= ls1
tetra.show(camera_position=[30,25,295], viewpoint= [[-0.3,-0.3,-1],100])
# Out:
# Graphics3d Object

# %% [markdown]
# Solving for the first and third circle intersections for the second perpendicular line.

# %%
sln2=solve([As1,As3],[x,y])
ps2x1=sln2[0][0].right()
ps2y1=sln2[0][1].right()
ps2x2=sln2[1][0].right()
ps2y2=sln2[1][1].right()
ls2=line3d([[ps2x1, ps2y1,0],[ps2x2,ps2y2,0]], thickness =2, radius =2)
tetra+= ls2
tetra.show(camera_position=[30,25,295], viewpoint= [[-0.3,-0.3,-1],100])
# Out:
# Graphics3d Object

# %% [markdown]
# Solving for the two lines perpendicular to the triangle base sides that contain the circle centers. It gives the apex projeced in the plane XY. The apex height z coordinate is computed from the triangle known sensor as the hypotenuse, and the vertex to the projected apex dimensions. The point is coincident with the platform location.

# %%
ms1=(ps1y2-ps1y1)/(ps1x2-ps1x1)
eq1=y-ps1y2-ms1*(x-ps1x2)==0
ms2=(ps2y2-ps2y1)/(ps2x2-ps2x1)
eq2=y-ps2y2-ms2*(x-ps2x2)==0
spr=solve([eq1,eq2],[x,y])
apx=spr[0][0].right().n()
apy=spr[0][1].right().n()

P3d = point3d((0,0,0), color='red', opacity=1, size=3) #Apex point
apxy = vector([apx,apy,0])
apr = P3d.translate(apxy)
dpxy3 = norm(apxy-A3)
apz=sqrt(la3m^2 - dpxy3^2)
ap=vector([apx,apy,-apz])

#draw apex and sensor lines
l1m1=line3d([ap,A1], color= 'black', thickness =2, radius =2)
l2m1=line3d([ap,A2], color= 'black', thickness =2, radius =2)
l3m1=line3d([ap,A3], color= 'black', thickness =2, radius =2)
aps=point3d(ap, color='green', opacity=1, size=3) #Apex point

sap = tetra + dotsb + t1 + t2 + t3 + aps + l1m1 + l2m1 + l3m1
print("apex A =", [apx,apy,-apz])

sap.show(viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=3.5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.1,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1)
sap.save('apexA.png', viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=3.5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.1,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1
    )
# Out:
# apex A = [-116.665478406775, -10.5892350677490, -109.894936255953]
# Graphics3d Object
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-7f54b8e66a55> in <module>
#      31     light_position=(RealNumber('4.0'), -RealNumber('4.0'), RealNumber('3.0')),
#      32     frame=false,axes = false,aspect_ratio=Integer(1))
# ---> 33 sap.save('apexA.png', viewer='threejs', antialiasing=True, raydepth=Integer(3),
#      34     figsize=[Integer(90),Integer(60)], # the image resolution is 100*figsize
#      35     camera_position=[Integer(3), Integer(4), Integer(2)], # a distant camera position combined with
#
# ~/shellPrograms/SageMath/local/lib/python3.9/site-packages/sage/plot/plot3d/base.pyx in sage.plot.plot3d.base.Graphics3d.save (build/cythonized/sage/plot/plot3d/base.c:24314)()
#    1905         elif ext in ['.bmp', '.png', '.gif', '.ppm', '.tiff', '.tif',
# ...

# %% [markdown]
# Computation for the tetrahedron B, defining the base plane and projecting it to the XY plane, computing the coordinates, and finally rotating back.

# %%
#angle from the base plane to the plane AP B1 B2
#directed vector from ap to B1
VapB1=(B1-ap)/norm(B1-ap)
#vector from ap to B2
VapB2=(B2-ap)/norm(B2-ap)
#normal vector to plane
VnB=VapB1.cross_product(VapB2)
#normalizevector
VnB=VnB/norm(VnB)
#unitary z vector
uz=vector([0,0,1])
#angle between vectors
beta = acos(uz.dot_product(VnB))
#rotation axis
raxB1B2 = (B2-B1)/norm(B2-B1)
#rotate Ap to the base plane
aprot = rotate_arbitrary(raxB1B2,-beta)*(ap-B1) + B1
#round to z = 0
aprot = vector([aprot[0],aprot[1],0])
lb1m=s4
lb2m=s5
ptab=norm(Bp0-Ap0)
#circles
Bs1=(x-B1[0])^2+(y-B1[1])^2-lb1m^2==0
Bs2=(x-B2[0])^2+(y-B2[1])^2-lb2m^2==0
Appl= (x-aprot[0])^2+(y-aprot[1])^2-ptab^2==0

auxeq1=Bs1-Appl
auxeq2=Bs2-Appl

#solving the two equations
sln1b=solve([auxeq1,auxeq2],[x,y])
xs1=sln1b[0][0].rhs().n()
ys1=sln1b[0][1].rhs().n()
sln1=vector([xs1,ys1,0])

bpx=sln1[0]
bpy=sln1[1]
bpxy=sln1
#find the height
dpxyb2 = norm(bpxy-B2)
bpz=sqrt(lb2m^2 - dpxyb2^2)
print("Apex B =", [bpx,bpy,-bpz])
# Out:
# Apex B = [1.52719283998034, -127.866213790352, -70.1032062884447]

# %% [markdown]
# There are two possible values after rotation, the selected height is validated from the platform side lenght.

# %%
#distance Bp Ap validation
bpr1=vector([bpx,bpy,-bpz])
bp1 = rotate_arbitrary(raxB1B2,beta)*(bpr1-B1)+B1
bpr2=vector([bpx,bpy,bpz])
bp2 = rotate_arbitrary(raxB1B2,beta)*(bpr2-B1)+B1

# %% [markdown]
# Apex C computation is similar to B. The all the three points are coincident with the original platform position.

# %%
#angle from the base plane to the plane AP C1 C3
#directed vector fron ap to C1
VapC1=(C1-ap)/norm(C1-ap)
#directed vector from ap to C3
VapC3=(C3-ap)/norm(C3-ap)
#normal vector to plane
VnC=VapC1.cross_product(VapC3)
#normalize vector
VnC=VnC/norm(VnC)
#find the angle betweeen unitary vector z to normal to VnC
gamma=acos(uz.dot_product(VnC))
#rotation axis
raxC1C3 = (C3-C1)/norm(C3-C1)
#rotate Ap to the base plane
aprotc = rotate_arbitrary(raxC1C3,-gamma)*(ap-C1) + C1
#round to z = 0
aprotc = vector([aprotc[0],aprotc[1],0])
lc1m=s6
lc3m=s7
ptac=norm(Cp0-Ap0)
#circles
Cs1=(x-C1[0])^2+(y-C1[1])^2-lc1m^2==0
Cs3=(x-C3[0])^2+(y-C3[1])^2-lc3m^2==0
Applc= (x-aprotc[0])^2+(y-aprotc[1])^2-ptac^2==0

eqaux1=Cs1-Applc
eqaux2=Cs3-Applc
#solve ftwo equations
sln2c=solve([eqaux1,eqaux2],[x,y])
xsc=sln2c[0][0].rhs().n()
ysc=sln2c[0][1].rhs().n()
slnc=vector([xsc,ysc,0])

cpx=slnc[0]
cpy=slnc[1]
cpxy=slnc

#find the height
dpxyc3 = norm(cpxy-C3)
cpz=sqrt(lc3m^2 - dpxyc3^2)
cpr1=vector([cpx,cpy,cpz])
cp1 = rotate_arbitrary(raxC1C3,gamma)*(cpr1-C1)+C1
cpr2=vector([cpx,cpy,-cpz])
cp2 = rotate_arbitrary(raxC1C3,gamma)*(cpr2-C1)+C1

# %%
dtol=20 #tolerance
dbpcp = norm(Bp0-Cp0) #reference distance

dbc11 = norm(bp1-cp1) #distance bp1 cp1
dbc12 = norm(bp1-cp2) #distance bp1 cp2
dbc21 = norm(bp2-cp1) #distance bp2 cp1
dbc22 = norm(bp2-cp2) #distance bp2 cp2

if abs(dbpcp-dbc11)<dtol:
    bp=bp1
    cp=cp1
elif abs(dbpcp-dbc12)<dtol:
    bp=bp1
    cp=cp2
elif abs(dbpcp-dbc21)<dtol:
    bp=bp2
    cp=cp1
elif abs(dbpcp-dbc22)<dtol:
    bp=bp2
    cp=cp2
else:
    print("the given sensor lenghts do not have solution")
#selected points
print(bp,cp)
# Out:
# (61.10610026474738, -97.6706205193527, -87.60117399454721) (55.37647443456733, 88.1270221987969, -93.47176588550812)

# %%
#draw circles, base triangle, sensors and points for B
s1cb=circle(B1,s4, color='magenta',thickness=2)
s2cb=circle(B2,s5, color='magenta',thickness=2)
sapr=circle(aprot,ptab, color='magenta',thickness=2)
trb=polygon([B1, B2, ap], color='orange')
trbp=polygon([B1, B2, aprot], color='orange')
l1m2=line3d([bp,B1], color='black',thickness=2, radius =2)
l2m2=line3d([bp,B2], color='black',thickness=2, radius =2)
sideab=line3d([bp,ap], color='green',thickness=2, radius =2)
bpdt = P3d.translate(bp)
aprdt= P3d.translate(aprot)
B1dt = P3d.translate(B1)
B2dt = P3d.translate(B2)
baseb=  s2cb + s1cb + sapr + bpdt + trb +l1m2 + l2m2 + sideab

tgrb= baseb  + aprdt + aps + B1dt +  B2dt  + trbp 

tgrb.show(viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=3.5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.2,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1)
tgrb.save('apexB.png', viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=3.5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.2,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1
    )
# Out:
# Graphics3d Object
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-8cd3db41b83d> in <module>
#      24     light_position=(RealNumber('4.0'), -RealNumber('4.0'), RealNumber('3.0')),
#      25     frame=false,axes = false,aspect_ratio=Integer(1))
# ---> 26 tgrb.save('apexB.png', viewer='threejs', antialiasing=True, raydepth=Integer(3),
#      27     figsize=[Integer(90),Integer(60)], # the image resolution is 100*figsize
#      28     camera_position=[Integer(3), Integer(4), Integer(2)], # a distant camera position combined with
#
# ~/shellPrograms/SageMath/local/lib/python3.9/site-packages/sage/plot/plot3d/base.pyx in sage.plot.plot3d.base.Graphics3d.save (build/cythonized/sage/plot/plot3d/base.c:24314)()
#    1905         elif ext in ['.bmp', '.png', '.gif', '.ppm', '.tiff', '.tif',
#    1906                      '.jpg', '.jpeg']:
# ...

# %%
#draw circles, triangle base, sensors and points for C
s1cc=circle(C1,s6, color='magenta',thickness=2)
s2cc=circle(C3,s7, color='magenta',thickness=2)
saprc=circle(aprotc,ptac, color='magenta',thickness=2)    
trc=polygon([C1, C3, ap], color='orange')
trcp=polygon([C1, C3, aprotc], color='orange')
l1m3=line3d([cp,C1], color='black',thickness=2, radius =2)
l2m3=line3d([cp,C3], color='black',thickness=2, radius =2)
sideac=line3d([cp,ap], color='green',thickness=2, radius =2)
cpdt = P3d.translate(cp)
aprdtc= P3d.translate(aprotc)
C1dt = P3d.translate(C1)
C3dt = P3d.translate(C3)    
basec=  s2cc + s1cc + saprc + cpdt + trc + l1m3 + l2m3 + sideac 

tgrc= basec + trcp +C1dt + C3dt + aprdtc + aps

tgrc.show(viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.2,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1)
tgrc.save('apexC.png', viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3, 4, 2], # a distant camera position combined with 
    zoom=5, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.2,-3.,-1.5), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1
    )
# Out:
# Graphics3d Object
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-b23048e59a7d> in <module>
#      24     light_position=(RealNumber('4.0'), -RealNumber('4.0'), RealNumber('3.0')),
#      25     frame=false,axes = false,aspect_ratio=Integer(1))
# ---> 26 tgrc.save('apexC.png', viewer='threejs', antialiasing=True, raydepth=Integer(3),
#      27     figsize=[Integer(90),Integer(60)], # the image resolution is 100*figsize
#      28     camera_position=[Integer(3), Integer(4), Integer(2)], # a distant camera position combined with
#
# ~/shellPrograms/SageMath/local/lib/python3.9/site-packages/sage/plot/plot3d/base.pyx in sage.plot.plot3d.base.Graphics3d.save (build/cythonized/sage/plot/plot3d/base.c:24314)()
#    1905         elif ext in ['.bmp', '.png', '.gif', '.ppm', '.tiff', '.tif',
#    1906                      '.jpg', '.jpeg']:
# ...

# %%
#Check sensor values and platform points
print(s1*.1.n(digits=3),s2*.1.n(digits=3),s3*.1.n(digits=3),s4*.1.n(digits=3),s5*.1.n(digits=3),s6*.1.n(digits=3),s7*.1.n(digits=3))
print(ap*.1.n(12,digits=3),bp*.1.n(digits=3),cp*.1.n(digits=3))
# Out:
# 11.0 12.6 12.5 14.8 10.8 15.2 11.9
# (-11.7, -1.06, -11.0) (6.11, -9.77, -8.76) (5.54, 8.81, -9.35)

# %%
platsol = polygon([ap, bp, cp], color='green')
tril=sap+baseb+basec+platsol
tril.show(viewer='threejs', antialiasing=True, raydepth=3,
    figsize=[80,50], # the image resolution is 100*figsize
    camera_position=[4, 4, 4], # a distant camera position combined with 
    zoom=4, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 1), # the camera is slightly tilted
    viewdir=(-2.1,-3.,-3), # slightly off-center
    light_position=(4.0, -4.0, 3.0),
    frame=false,axes = false,aspect_ratio=1)

tril.save('tril1.png',viewer='tachyon', antialiasing=True, raydepth=3,
    figsize=[90,60], # the image resolution is 100*figsize
    camera_position=[3.70,-0.15,6.10],# a distant camera position combined with 
    zoom=4, # a large zoom factor will decrease perspective distortion.
    updir=(0, 0, 2), # the camera is slightly tilted
    viewdir=(-3.70,0.15,-6.10), # slightly off-center
    light_position=(-10.0, 10.0, 10.0),
    frame=false,axes = false,aspect_ratio=[1,1,1])
# Out:
# Graphics3d Object
